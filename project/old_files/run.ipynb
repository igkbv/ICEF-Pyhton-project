# %%
def run():
    #it's okay if it takes a while to run
    # %run member2_final.ipynb
    # %run member3.ipynb
run()
# Out:
# {'url': 'https://www.google.com', 'timestamp': '2026-03-21 06:01:13', 'status': 'success', 'status_code': 200, 'response_time': 0.74, 'error_type': None}
# {'url': 'https://github.com', 'timestamp': '2026-03-21 06:01:14', 'status': 'success', 'status_code': 200, 'response_time': 0.871, 'error_type': None}
# {'url': 'https://www.wikipedia.org', 'timestamp': '2026-03-21 06:01:15', 'status': 'failed', 'status_code': None, 'response_time': None, 'error_type': 'connection_error'}
# {'url': 'https://stackoverflow.com', 'timestamp': '2026-03-21 06:01:15', 'status': 'success', 'status_code': 200, 'response_time': 1.145, 'error_type': None}
# {'url': 'https://www.youtube.com', 'timestamp': '2026-03-21 06:01:17', 'status': 'failed', 'status_code': None, 'response_time': None, 'error_type': 'connection_error'}
# {'url': 'https://web.telegram.org', 'timestamp': '2026-03-21 06:01:17', 'status': 'failed', 'status_code': None, 'response_time': None, 'error_type': 'timeout'}
# ...
